# %% [markdown]
# # Dataset Creation
# At the top level, we have access to CLEF2019 and the SYNERGY dataset.
#
# The slight advantage of SYNERGY is that it has a few systematic reviews (SRs) from outside the biomedical domain; CLEF is only within biomedicine.
#
# However, CLEF has 92 reviews in total, which is massive.
#
# Let's just start by accessing both within this notebook, before looking to combine them in some way.

# %% [markdown]
# ## We begin with CLEF!

# %%
# std lib imports 
import pickle as pkl

# pkg imports
import pandas as pd

# %%
# path to the CLEF dataset
clef_path = "./data/Clef/CLEF2019/"

# %%
clef19_train = pd.DataFrame(pd.read_pickle(clef_path + "CLEF2019_training_data.pkl"))
clef19_test = pd.DataFrame(pd.read_pickle(clef_path + "CLEF2019_test_data.pkl"))

# %%
# combine the train and test sets into one and tranpose it
clef19 = pd.concat([clef19_train, clef19_test], axis=1).T
# drop unnecessery columns
clef19 = clef19.drop(['query', 'type', 'terms_meshs'], axis=1)
clef19
# Out:
#                                                       title  \
# CD007394  Galactomannan detection for invasive aspergill...
# CD007427  Physical tests for shoulder impingements and l...
# CD008054  Human papillomavirus testing versus repeat cyt...
# CD008081  Optical coherence tomography (OCT) for detecti...
# CD008122  Rapid diagnostic tests for diagnosing uncompli...
# ...                                                     ...
# CD012669  Point‐of‐care ultrasonography for diagnosing t...
# CD012768  Xpert® MTB/RIF assay for extrapulmonary tuberc...
# CD012661  Development of type 2 diabetes mellitus in peo...
# CD011558  Factors that influence the provision of intrap...
# CD011787  Parents' and informal caregivers' views and ex...
#
#                                                    included  \
# CD007394  {'ids_abs': ['24049291', '23644098', '23614624...
# CD007427  {'ids_abs': ['19230608', '19181972', '19059895...
# CD008054  {'ids_abs': ['20856930', '20713299', '20708786...
# CD008081  {'ids_abs': ['21996307', '9479300', '17502499'...
# CD008122  {'ids_abs': ['15361993', '19187517', '10715695...
# ...                                                     ...
# CD012669  {'ids_abs': ['24073336', '22307581', '25405557...
# CD012768  {'ids_abs': ['21396219', '23827859', '25574911...
# CD012661  {'ids_abs': ['26675051', '24083174', '25093755...
# CD011558  {'ids_abs': ['23394288', '23234509'], 'ids_con...
# CD011787  {'ids_abs': ['22333837', '17376937', '17959583...
#
#                                              search_results
# CD007394  {'ids': ['24514094', '24505528', '24495193', '...
# CD007427  {'ids': ['16396700', '16539812', '17543142', '...
# CD008054  {'ids': ['20301575', '20301650', '21271014', '...
# CD008081  {'ids': ['23793175', '23768471', '23767192', '...
# CD008122  {'ids': ['19164769', '9557953', '7688346', '18...
# ...                                                     ...
# CD012669  {'ids': ['26973754', '23911136', '20622617', '...
# CD012768  {'ids': ['22815718', '27286562', '22381459', '...
# CD012661  {'ids': ['25954454', '26675051', '27476051', '...
# CD011558  {'ids': ['25364879', '24290947', '23461026', '...
# CD011787  {'ids': ['9673053', '9493807', '23641449', '12...
#
# [123 rows x 3 columns]

# %%
def parse_row(row: pd.Series, citation_id: str) -> pd.DataFrame:
    included_ids_abs = set(row['included']['ids_abs'])
    included_ids_cont = set(row['included']['ids_cont'])
    search_results = row['search_results']

    df = pd.DataFrame()

    # add the OpenAlex ids
    df['oa_id'] = search_results['ids']
    # add original citation's id
    df['citation_id'] = citation_id
    
    # get the titles and abstracts
    titles, abstracts = [], []
    for record in search_results['records']:
        _, title, abstract, _ = record
        titles.append(title)
        abstracts.append(float('nan') if abstract == "?" else abstract)
        
    df['title'] = titles 
    df['abstract'] = abstracts

    # the ids that passed screening at the title+abstract level
    df['label_included'] = df['oa_id'].apply(lambda id: 1 if id in included_ids_abs else 0)

    # the ids that passed screening at the full content level
    df['label_included_content'] = df['oa_id'].apply(lambda id: 1 if id in included_ids_cont else 0)
    
    return df

# %%
# combine the srs into a single dataset
cleaned_clef = pd.concat([parse_row(row,citation_id) for citation_id,row in clef19.iterrows()], ignore_index=True)
cleaned_clef
# Out:
#            oa_id citation_id  \
# 0       24514094    CD007394
# 1       24505528    CD007394
# 2       24495193    CD007394
# 3       24493565    CD007394
# 4       24489964    CD007394
# ...          ...         ...
# 574226  25424785    CD011787
# 574227   9695135    CD011787
# 574228  16700379    CD011787
# 574229  24412301    CD011787
# 574230  15481207    CD011787
#
#                                                     title  \
# 0       Susceptibility breakpoints for amphotericin B ...
# 1       The prevalence of antifungal agents administra...
# 2       Serum and urine Blastomyces antigen concentrat...
# 3       Directed modification of the Aspergillus usami...
# 4       Earlier diagnosis of invasive fusariosis with ...
# ...                                                   ...
# 574226  Immunogenicity and safety of the HPV-16/18 AS0...
# 574227  Influence of socioeconomic status on behaviora...
# 574228  Serosurvey of hepatitis B surface antigen in p...
# 574229  Evaluation of the feasibility of a state-based...
# 574230  Delivering a selective neonatal BCG vaccinatio...
#
#                                                  abstract  label_included  \
# 0       Although conventional amphotericin B was for m...               0
# 1       BACKGROUND: Invasive fungal infections (IFIs) ...               0
# 2       BACKGROUND: Serum and urine Blastomyces antige...               0
# 3       beta-Mannanases (EC 3.2.1.78) can catalyze the...               0
# 4       Cross-reactivity of Fusarium species with seru...               0
# ...                                                   ...             ...
# 574226  Immunogenicity and safety of the human papillo...               0
# 574227  A double-blind prospective design was used to ...               0
# 574228  In 1990, Saudi Arabia began vaccinating all ch...               0
# 574229  The vaccine safety advice network is a collabo...               0
# 574230  Neonatal bacillus Calmette-Guerin (BCG) immuni...               0
#
#         label_included_content
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 574226                       0
# 574227                       0
# 574228                       0
# 574229                       0
# 574230                       0
#
# [574231 rows x 6 columns]

# %%
# save the combined + cleaned dataset
cleaned_clef.to_pickle(clef_path + "CLEF2019_combined_data.pkl")

# %% [markdown]
# ## Now for SYNERGY
# We'll open each file and combine it into one.

# %%
# std lib import
from os import listdir

# %%
# path to the SYNERGY dataset directory
synergy_path = "./data/synergy_dataset/"

# %%
synergy_csvs = [file for file in listdir(synergy_path) if file[-4:] == '.csv']

# %%
def parse_synergy_dataset(file_path: str, citation_id: str) -> pd.DataFrame:
    df = pd.read_csv(file_path)
    df.insert(1, "citation_id", citation_id)
    return df

# %%
combined_synergy = pd.concat([parse_synergy_dataset(synergy_path + csv, csv[:-4]) for csv in synergy_csvs], ignore_index=True)
combined_synergy
# Out:
#                                                      doi   citation_id  \
# 0            https://doi.org/10.1109/indcon.2010.5712716     Hall_2012
# 1          https://doi.org/10.1109/induscon.2010.5740045     Hall_2012
# 2              https://doi.org/10.1109/tpwrd.2005.848672     Hall_2012
# 3          https://doi.org/10.1109/icelmach.2008.4799852     Hall_2012
# 4             https://doi.org/10.1109/ipdps.2006.1639408     Hall_2012
# ...                                                  ...           ...
# 169283                 https://doi.org/10.1002/jts.21893  van_Dis_2020
# 169284                  https://doi.org/10.1037/a0026361  van_Dis_2020
# 169285  https://doi.org/10.1097/00005131-199903000-00004  van_Dis_2020
# 169286        https://doi.org/10.1037//0022-006x.68.1.31  van_Dis_2020
# 169287      https://doi.org/10.1080/15402002.2012.755125  van_Dis_2020
#
#                                                     title  \
# 0       Computer vision based offset error computation...
# 1       Design and development of a software for fault...
# 2       Analytical Approach to Internal Fault Simulati...
# 3       Nonlinear equivalent circuit model of a tracti...
# 4                     Fault tolerance with real-time Java
# ...                                                   ...
# 169283  Effects of Cognitive-Behavioral Conjoint Thera...
# 169284  Attendance and substance use outcomes for the ...
# 169285  Segment Transport Employing Intramedullary Dev...
# 169286  Cognitive-behavioral stress management interve...
# 169287  Bad Dream Frequency in Older Adults With Gener...
#
#                                                  abstract  label_included
# 0       The use of computer vision based approach has ...               0
# 1       This paper presents an on-line fault diagnosis...               0
# 2       A new method for simulating faulted transforme...               0
# 3       The paper presents the development of an equiv...               0
# 4       After having drawn up a state of the art on th...               0
# ...                                                   ...             ...
# 169283                                                 en               0
# 169284  This study uses data from the largest effectiv...               0
# 169285  To compare two different methods of segment tr...               0
# 169286  The present study tested the effects of a mult...               0
# 169287  This study investigated the relation between g...               0
#
# [169288 rows x 5 columns]

# %%
# save the combined + cleaned dataset
combined_synergy.to_pickle(synergy_path + "SYNERGY_combined_data.pkl")
